# %% [markdown]
# <a href="https://colab.research.google.com/github/NIRA05/CareNova/blob/main/salary_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv")

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (40, 2)

# %%
import matplotlib.pyplot as plt

# %%
x=df[["Experience Years"]]
y=df["Salary"]
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y,train_size=0.7,random_state=2529)

# %%
 x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((28, 1), (28,), (12, 1), (12,))

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=2529)

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)*100
# Out:
# 95.34676826438887

# %%
lr.predict([[5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([73625.04447275])

# %%
lr.predict([[10]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([120653.12763442])

# %%
year=float(input("enter your year:"))
print(lr.predict([[year]]))
# Out:
# enter your year:1.2
# [37883.70126987]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
lr.coef_
# Out:
# array([9405.61663234])

# %%
lr.intercept_
# Out:
# np.float64(26596.961311068262)

# %%
x=df[["Experience Years"]]
y=df["Salary"]
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color="red")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
